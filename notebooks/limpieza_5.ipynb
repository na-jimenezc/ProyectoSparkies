# %%
dfUNIDOS = spark.read.csv("/Volumes/catalogproyectosparkies/default/volumeproyectosparkies/Beneficiarios-Estrategia-UNIDOS.csv",header=True, inferSchema=True)
dfUNIDOS.createOrReplaceTempView("dfUNIDOS")
display(dfUNIDOS)
