# %%
dfEstadisticaPorMunicipio = spark.read.csv("/Volumes/catalogproyectosparkies/default/volumeproyectosparkies/Estadísticas-de-Educación-en-Preescolar-Básica-y-Media-por-Municipio.csv",header=True, inferSchema=True)
dfEstadisticaPorMunicipio.createOrReplaceTempView("dfEstadisticaPorMunicipio")
display(dfEstadisticaPorMunicipio)
