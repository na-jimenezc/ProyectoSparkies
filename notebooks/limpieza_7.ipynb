# %%
dfMatriculaPorMunicipio = spark.read.csv("/Volumes/catalogproyectosparkies/default/volumeproyectosparkies/Estadísticas-Matrícula-por-Municipio.csv",header=True, inferSchema=True)
dfMatriculaPorMunicipio.createOrReplaceTempView("dfMatriculaPorMunicipio")
display(dfMatriculaPorMunicipio)
